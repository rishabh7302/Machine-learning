# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabh7302/Machine-learning/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import fetch_california_housing
data=fetch_california_housing(as_frame=True)

# %%
data
# Out:
# {'data':        MedInc  HouseAge  AveRooms  ...  AveOccup  Latitude  Longitude
#  0      8.3252      41.0  6.984127  ...  2.555556     37.88    -122.23
#  1      8.3014      21.0  6.238137  ...  2.109842     37.86    -122.22
#  2      7.2574      52.0  8.288136  ...  2.802260     37.85    -122.24
#  3      5.6431      52.0  5.817352  ...  2.547945     37.85    -122.25
#  4      3.8462      52.0  6.281853  ...  2.181467     37.85    -122.25
#  ...       ...       ...       ...  ...       ...       ...        ...
#  20635  1.5603      25.0  5.045455  ...  2.560606     39.48    -121.09
#  20636  2.5568      18.0  6.114035  ...  3.122807     39.49    -121.21
#  20637  1.7000      17.0  5.205543  ...  2.325635     39.43    -121.22
#  20638  1.8672      18.0  5.329513  ...  2.123209     39.43    -121.32
#  20639  2.3886      16.0  5.254717  ...  2.616981     39.37    -121.24
#
#  [20640 rows x 8 columns],
#  'target': 0        4.526
#  1        3.585
#  2        3.521
#  3        3.413
# ...

# %%
x=data.data
y=data.target

# %%
print(x.shape)
print(y.shape)
# Out:
# (20640, 8)
# (20640,)

# %%
print(x.head())
print(y.head())
# Out:
#    MedInc  HouseAge  AveRooms  ...  AveOccup  Latitude  Longitude
# 0  8.3252      41.0  6.984127  ...  2.555556     37.88    -122.23
# 1  8.3014      21.0  6.238137  ...  2.109842     37.86    -122.22
# 2  7.2574      52.0  8.288136  ...  2.802260     37.85    -122.24
# 3  5.6431      52.0  5.817352  ...  2.547945     37.85    -122.25
# 4  3.8462      52.0  6.281853  ...  2.181467     37.85    -122.25
#
# [5 rows x 8 columns]
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedHouseVal, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (16512, 8)
# (16512,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [ 4.48674910e-01  9.72425752e-03 -1.23323343e-01  7.83144907e-01
#  -2.02962058e-06 -3.52631849e-03 -4.19792487e-01 -4.33708065e-01]

# %%
print(model.intercept_)
# Out:
# -37.02327770606409

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0.71912284, 1.76401657, 2.70965883, ..., 4.46877017, 1.18751119,
#        2.00940251])

# %% [markdown]
# # R2 score

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.5757877060324508

# %% [markdown]
# # calculate MAE

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.5332001304956553

# %% [markdown]
# # mean squared error

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 0.5558915986952444
